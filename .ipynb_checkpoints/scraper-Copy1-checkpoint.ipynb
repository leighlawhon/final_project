# %%
from bs4 import BeautifulSoup
import urllib2

fp = urllib2.urlopen("https://www.indeed.com/resumes?q=booz+allen+&l=Ashburn%2C+VA").read()
soup = BeautifulSoup(fp, 'html.parser')
print soup.prettify()
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <script src="//cdn.optimizely.com/js/7275028.js">
#   </script>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    booz allen resumes in Ashburn, VA | Indeed Resume Search
#   </title>
#   <meta content="Find booz allen resumes in Ashburn, VA today on Indeed Resume. Fast, simple resume search." name="description"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="115882278440564" property="fb:app_id"/>
#   <meta content="indeedjobs:indeed_resume" property="og:type"/>
#   <meta content="I'm one of the thousands of employers already using Indeed to access millions of resumes. Fast, simple resume search." property="og:description"/>
#   <meta content="https://www.indeed.com/resumes" property="og:url"/>
#   <meta content="http://labkit.indeed.com/static/indeed_fb.png" property="og:image"/>
# ...

# %%
import textract
text = textract.process("path/to/file.extension")
